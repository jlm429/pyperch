# %% [markdown]
# ## Hyperparameter Search with Simulated Annealing (Optuna)
#
# This example demonstrates how to perform hyperparameter search for a Simulated Annealing training setup using **Optuna** and pyperch’s search utilities.
#
# A fixed base training configuration is defined, and Optuna is used to explore SA-specific hyperparameters such as temperature, cooling rate, step size, and training duration.  The objective is to maximize validation accuracy on a binary classification task.

# %%
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

from pyperch import Trainer
from pyperch.config import TrainConfig, OptimizerConfig
from pyperch.core.metrics import Accuracy
from pyperch.models.mlp import SimpleMLP
from pyperch.core.callbacks import EarlyStopping, CallbackList

# Search components
from pyperch.search.strategy import OptunaStrategy
from pyperch.search.builder import TrainConfigBuilder
from pyperch.search.adapter import TrainerAdapter
from pyperch.search.factory import SearchFactory

# ------------------------------------------------------------
# 1. Reproducibility
# ------------------------------------------------------------
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

# ------------------------------------------------------------
# 2. Dataset
# ------------------------------------------------------------
X, y = make_classification(
    n_samples=1000,
    n_features=12,
    n_informative=10,
    n_classes=2,
    random_state=seed,
)

X = X.astype(np.float32)
y = y.astype(np.int64)

X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.2, random_state=seed
)

train_loader = DataLoader(
    TensorDataset(torch.tensor(X_train), torch.tensor(y_train)),
    batch_size=64,
    shuffle=True,
)

valid_loader = DataLoader(
    TensorDataset(torch.tensor(X_valid), torch.tensor(y_valid)),
    batch_size=64,
)

# ------------------------------------------------------------
# 3. Base training configuration
# ------------------------------------------------------------
base_opt_cfg = OptimizerConfig(
    name="sa",
    t=1.0,
    t_min=0.01,
    step_size=0.05,
    cooling=0.95,
)

base_cfg = TrainConfig(
    device="cpu",
    seed=seed,
    max_epochs=300,
    optimizer="sa",
    optimizer_config=base_opt_cfg,
    optimizer_mode="per_batch",   
    metrics={"train": [Accuracy()], "valid": [Accuracy()]},
)

builder = TrainConfigBuilder(base_cfg)

# ------------------------------------------------------------
# 4. Optuna search space
# ------------------------------------------------------------
def suggest_params(trial):
    return {
        "optimizer_config.t": trial.suggest_float("t", 0.5, 2.0),
        "optimizer_config.t_min": trial.suggest_float("t_min", 0.001, 0.01),
        "optimizer_config.step_size": trial.suggest_float("step_size", 0.025, 0.05),
        "optimizer_config.cooling": trial.suggest_float("cooling", 0.90, 0.999),
        "max_epochs": trial.suggest_int("max_epochs", 10, 200),
    }

strategy = OptunaStrategy(suggest_params)

# ------------------------------------------------------------
# 5. Callbacks
# ------------------------------------------------------------
# Early stopping reduces search runtime
early_stopping = EarlyStopping(
    monitor="valid_loss",   # loss is always minimized
    patience=15,
    min_delta=1e-4,
)

# ------------------------------------------------------------
# 6. Training function (Optuna objective)
# ------------------------------------------------------------
def train_fn(cfg):
    model = SimpleMLP(
        input_dim=12,
        hidden=[32],
        output_dim=2,
        activation="relu",
    )

    loss_fn = nn.CrossEntropyLoss()

    trainer = Trainer(
        model=model,
        config=cfg,
        loss_fn=loss_fn,
    )

    # Ensure default callbacks (e.g., HistoryCallback) are preserved
    if trainer.callbacks is None:
        trainer.callbacks = CallbackList()

    trainer.callbacks.append(early_stopping)

    history = trainer.fit(train_loader, valid_loader)

    # Optuna objective: best validation accuracy achieved
    return max(history["valid_metrics"].get("accuracy", [0.0]))

adapter = TrainerAdapter(builder, strategy, train_fn)

# ------------------------------------------------------------
# 7. Run search
# ------------------------------------------------------------
import optuna

optuna.delete_study(
    study_name="sa_search_demo",
    storage="sqlite:///sa_demo.db",
)

search = SearchFactory.optuna_sqlite(
    adapter=adapter,
    study_name="sa_search_demo",
    storage="sqlite:///sa_demo.db",
)

study = search.run(
    n_trials=150,
    n_jobs=4,  # use -1 for all available cores
)

print("Best parameters:", search.best_params)
print("Best score:", search.best_value)
print("Best trial:", search.best_trial.number)
# Out:
# [I 2025-12-12 03:04:25,339] A new study created in RDB with name: sa_search_demo
# [I 2025-12-12 03:04:26,682] Trial 0 finished with value: 0.555 and parameters: {'t': 1.1356285009476135, 't_min': 0.0054114058870892694, 'step_size': 0.03967622302766703, 'cooling': 0.9745954523435062, 'max_epochs': 10}. Best is trial 0 with value: 0.555.
# [I 2025-12-12 03:04:29,531] Trial 4 finished with value: 0.715 and parameters: {'t': 0.583053501242841, 't_min': 0.0021783023304412117, 'step_size': 0.049642719433669415, 'cooling': 0.9623734728647027, 'max_epochs': 125}. Best is trial 4 with value: 0.715.
# [I 2025-12-12 03:04:30,551] Trial 1 finished with value: 0.615 and parameters: {'t': 1.8032642119217235, 't_min': 0.008247979048161512, 'step_size': 0.03395370073297856, 'cooling': 0.927371655531226, 'max_epochs': 188}. Best is trial 4 with value: 0.715.
# [I 2025-12-12 03:04:30,735] Trial 2 finished with value: 0.515 and parameters: {'t': 1.8342480161390515, 't_min': 0.0028028019785117306, 'step_size': 0.04323251350437261, 'cooling': 0.9944901354637479, 'max_epochs': 163}. Best is trial 4 with value: 0.715.
# [I 2025-12-12 03:04:33,899] Trial 6 finished with value: 0.56 and parameters: {'t': 0.9627740228856071, 't_min': 0.003248775613756555, 'step_size': 0.04261722678399682, 'cooling': 0.9477613682995857, 'max_epochs': 90}. Best is trial 4 with value: 0.715.
# [I 2025-12-12 03:04:34,117] Trial 3 finished with value: 0.86 and parameters: {'t': 0.5835824769050657, 't_min': 0.001810413819371178, 'step_size': 0.0457338679570872, 'cooling': 0.9281705505474588, 'max_epochs': 92}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:34,273] Trial 5 finished with value: 0.74 and parameters: {'t': 1.122870740520737, 't_min': 0.009848130567237077, 'step_size': 0.03194298133641279, 'cooling': 0.9457407286623875, 'max_epochs': 190}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:34,481] Trial 7 finished with value: 0.63 and parameters: {'t': 1.3310570582644878, 't_min': 0.007714295016692703, 'step_size': 0.025194117098010987, 'cooling': 0.9075143383528167, 'max_epochs': 72}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:34,641] Trial 8 finished with value: 0.635 and parameters: {'t': 1.3718190719909145, 't_min': 0.00834602824667691, 'step_size': 0.04505237168717715, 'cooling': 0.9184371085471944, 'max_epochs': 118}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:34,851] Trial 9 finished with value: 0.58 and parameters: {'t': 1.683196802469812, 't_min': 0.001233727762790371, 'step_size': 0.04168285109436677, 'cooling': 0.9542656895665786, 'max_epochs': 43}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:35,072] Trial 10 finished with value: 0.515 and parameters: {'t': 0.7891091227789866, 't_min': 0.009869175345019871, 'step_size': 0.03860562652966197, 'cooling': 0.9276275557729113, 'max_epochs': 145}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:35,285] Trial 11 finished with value: 0.56 and parameters: {'t': 1.3234616611480545, 't_min': 0.004748412387238658, 'step_size': 0.046209199927704434, 'cooling': 0.9658195052412569, 'max_epochs': 63}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:35,492] Trial 12 finished with value: 0.4 and parameters: {'t': 1.7502106271350284, 't_min': 0.006332257195577712, 'step_size': 0.04662186035416983, 'cooling': 0.9848281653446436, 'max_epochs': 118}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:35,701] Trial 13 finished with value: 0.43 and parameters: {'t': 0.6082197514759552, 't_min': 0.004739858350690141, 'step_size': 0.04990422056691184, 'cooling': 0.9274065158034692, 'max_epochs': 147}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:35,911] Trial 14 finished with value: 0.415 and parameters: {'t': 0.56337067341281, 't_min': 0.004955519107859605, 'step_size': 0.03223739825656256, 'cooling': 0.939542129943259, 'max_epochs': 199}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:36,124] Trial 15 finished with value: 0.565 and parameters: {'t': 0.5028074196306962, 't_min': 0.006862291661287509, 'step_size': 0.032820797187305475, 'cooling': 0.9399107048737653, 'max_epochs': 182}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:36,333] Trial 16 finished with value: 0.565 and parameters: {'t': 0.5349616833805377, 't_min': 0.009958183706153059, 'step_size': 0.032326723879733524, 'cooling': 0.9413470639345152, 'max_epochs': 199}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:36,548] Trial 17 finished with value: 0.565 and parameters: {'t': 0.8826613369021656, 't_min': 0.006676171188858472, 'step_size': 0.03255498600101752, 'cooling': 0.9383112408659104, 'max_epochs': 197}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:36,760] Trial 18 finished with value: 0.565 and parameters: {'t': 0.9712452311262425, 't_min': 0.009855500256766484, 'step_size': 0.03440814978120493, 'cooling': 0.9027838461554669, 'max_epochs': 94}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:36,975] Trial 19 finished with value: 0.56 and parameters: {'t': 0.8836437461522338, 't_min': 0.009602013066153466, 'step_size': 0.02757954687483047, 'cooling': 0.900452669268641, 'max_epochs': 94}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:37,184] Trial 20 finished with value: 0.56 and parameters: {'t': 0.8433254681061402, 't_min': 0.003909370805228877, 'step_size': 0.028024345880222734, 'cooling': 0.9028236664748719, 'max_epochs': 91}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:37,384] Trial 21 finished with value: 0.56 and parameters: {'t': 1.550331668753123, 't_min': 0.0038983549246189996, 'step_size': 0.02721351537151359, 'cooling': 0.9182094287027618, 'max_epochs': 94}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:37,628] Trial 22 finished with value: 0.56 and parameters: {'t': 1.5401848768739486, 't_min': 0.004042228627871269, 'step_size': 0.027576885855566384, 'cooling': 0.9114628550150033, 'max_epochs': 42}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:37,897] Trial 23 finished with value: 0.505 and parameters: {'t': 1.5977822273350726, 't_min': 0.0038578726733979893, 'step_size': 0.028751844045626664, 'cooling': 0.9153504512982923, 'max_epochs': 35}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:38,119] Trial 24 finished with value: 0.38 and parameters: {'t': 1.5435568973187843, 't_min': 0.0011937272580801646, 'step_size': 0.04989563202990442, 'cooling': 0.9579933401839328, 'max_epochs': 128}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:38,344] Trial 25 finished with value: 0.56 and parameters: {'t': 0.6780545633405013, 't_min': 0.0010092317208721916, 'step_size': 0.04936590739806916, 'cooling': 0.9603693069011912, 'max_epochs': 132}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:38,592] Trial 26 finished with value: 0.38 and parameters: {'t': 1.9821343114798786, 't_min': 0.0011952829983168396, 'step_size': 0.0498143677529814, 'cooling': 0.9624097189143265, 'max_epochs': 126}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:38,853] Trial 27 finished with value: 0.475 and parameters: {'t': 0.7064001785027937, 't_min': 0.0011794571392741318, 'step_size': 0.049448211889135445, 'cooling': 0.9608221871575057, 'max_epochs': 131}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:39,080] Trial 28 finished with value: 0.485 and parameters: {'t': 0.6851000055373826, 't_min': 0.0025023527991634657, 'step_size': 0.04807009493745712, 'cooling': 0.9640492949120674, 'max_epochs': 167}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:39,298] Trial 29 finished with value: 0.565 and parameters: {'t': 1.1331608310993142, 't_min': 0.002378294407956804, 'step_size': 0.04751620907142032, 'cooling': 0.9654435034644965, 'max_epochs': 168}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:39,492] Trial 30 finished with value: 0.565 and parameters: {'t': 1.1719925645138416, 't_min': 0.002251759672832928, 'step_size': 0.03550525810239062, 'cooling': 0.9690989013277171, 'max_epochs': 169}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:39,733] Trial 31 finished with value: 0.565 and parameters: {'t': 1.1197054381372804, 't_min': 0.0027182874916122112, 'step_size': 0.036126242119525, 'cooling': 0.9715333238427413, 'max_epochs': 169}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:39,959] Trial 32 finished with value: 0.56 and parameters: {'t': 1.0796366996426328, 't_min': 0.002225141770565743, 'step_size': 0.04040231301245291, 'cooling': 0.9735350538864481, 'max_epochs': 71}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:40,187] Trial 33 finished with value: 0.55 and parameters: {'t': 1.0907947781485028, 't_min': 0.0019594753641430326, 'step_size': 0.0364948605104486, 'cooling': 0.9745675901145622, 'max_epochs': 16}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:40,414] Trial 34 finished with value: 0.405 and parameters: {'t': 1.3788061274089096, 't_min': 0.008666060677495957, 'step_size': 0.04477394654390668, 'cooling': 0.9789178319410732, 'max_epochs': 115}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:40,642] Trial 35 finished with value: 0.555 and parameters: {'t': 1.4099192516540038, 't_min': 0.008771615770255994, 'step_size': 0.04526148727464526, 'cooling': 0.9203333095635273, 'max_epochs': 105}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:40,762] Trial 36 finished with value: 0.555 and parameters: {'t': 1.3390638611260741, 't_min': 0.009002046018480897, 'step_size': 0.044511187037769934, 'cooling': 0.9321811183350276, 'max_epochs': 113}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:41,045] Trial 37 finished with value: 0.555 and parameters: {'t': 1.4465835641963427, 't_min': 0.008907782128630557, 'step_size': 0.044102827062775636, 'cooling': 0.9324533727063473, 'max_epochs': 108}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:41,267] Trial 38 finished with value: 0.525 and parameters: {'t': 1.4502788291546262, 't_min': 0.008966414137539385, 'step_size': 0.04434465570329589, 'cooling': 0.9215724369802402, 'max_epochs': 107}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:41,527] Trial 40 finished with value: 0.44 and parameters: {'t': 1.230525916960836, 't_min': 0.007756455116305065, 'step_size': 0.043383013482954244, 'cooling': 0.9487813056663331, 'max_epochs': 151}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:41,652] Trial 39 finished with value: 0.495 and parameters: {'t': 1.2438313158161574, 't_min': 0.007770675363389459, 'step_size': 0.043394672197095904, 'cooling': 0.9487852816727351, 'max_epochs': 148}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:41,918] Trial 41 finished with value: 0.52 and parameters: {'t': 1.1989645755802183, 't_min': 0.0033049310577431285, 'step_size': 0.04198129901368673, 'cooling': 0.9482168498353041, 'max_epochs': 148}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:42,052] Trial 42 finished with value: 0.5 and parameters: {'t': 1.0219616009556998, 't_min': 0.007503863165845193, 'step_size': 0.04154024064890115, 'cooling': 0.9481446089604837, 'max_epochs': 148}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:42,373] Trial 43 finished with value: 0.495 and parameters: {'t': 0.9827315337846079, 't_min': 0.00737475194907716, 'step_size': 0.030862558491378835, 'cooling': 0.9114357763617488, 'max_epochs': 75}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:42,580] Trial 44 finished with value: 0.43 and parameters: {'t': 0.6172130386419458, 't_min': 0.005873482550555351, 'step_size': 0.02590118420491192, 'cooling': 0.9099442085488416, 'max_epochs': 65}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:42,814] Trial 46 finished with value: 0.395 and parameters: {'t': 1.3194358191548288, 't_min': 0.0016812646993874028, 'step_size': 0.029937006196152825, 'cooling': 0.9076415292842533, 'max_epochs': 72}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:42,931] Trial 45 finished with value: 0.425 and parameters: {'t': 0.771248454563773, 't_min': 0.0057262448821916966, 'step_size': 0.02998596389458012, 'cooling': 0.9113936836313443, 'max_epochs': 69}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:43,199] Trial 47 finished with value: 0.49 and parameters: {'t': 1.2946519016965605, 't_min': 0.006072366440540394, 'step_size': 0.04670863300167056, 'cooling': 0.9239062560452768, 'max_epochs': 75}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:43,426] Trial 48 finished with value: 0.505 and parameters: {'t': 0.7587343329465707, 't_min': 0.0016662494850058223, 'step_size': 0.029910265685997264, 'cooling': 0.9550361928769042, 'max_epochs': 80}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:43,695] Trial 50 finished with value: 0.435 and parameters: {'t': 1.7497947222968584, 't_min': 0.009312134698787068, 'step_size': 0.03929760689115868, 'cooling': 0.9983984067332505, 'max_epochs': 81}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:43,833] Trial 49 finished with value: 0.56 and parameters: {'t': 1.6610437734774004, 't_min': 0.008271301817486587, 'step_size': 0.038176663750563444, 'cooling': 0.9245659995240925, 'max_epochs': 80}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:44,049] Trial 51 finished with value: 0.515 and parameters: {'t': 1.7191008459107915, 't_min': 0.008198911243755654, 'step_size': 0.03820958914919487, 'cooling': 0.9324022934685343, 'max_epochs': 53}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:44,275] Trial 52 finished with value: 0.5 and parameters: {'t': 1.8246364844337268, 't_min': 0.009307538777593041, 'step_size': 0.03854965518282233, 'cooling': 0.9329526739284345, 'max_epochs': 60}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:44,602] Trial 53 finished with value: 0.495 and parameters: {'t': 1.9366116119980696, 't_min': 0.006910555045946127, 'step_size': 0.033497564205619265, 'cooling': 0.9365482606493248, 'max_epochs': 182}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:44,714] Trial 54 finished with value: 0.425 and parameters: {'t': 1.8444272495364016, 't_min': 0.006883670584262711, 'step_size': 0.03373508318609992, 'cooling': 0.9428315083915064, 'max_epochs': 186}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:44,913] Trial 55 finished with value: 0.425 and parameters: {'t': 1.8211913683417573, 't_min': 0.006855761965787634, 'step_size': 0.03403789799726924, 'cooling': 0.9425320454394223, 'max_epochs': 191}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:45,125] Trial 56 finished with value: 0.425 and parameters: {'t': 1.92062076605811, 't_min': 0.0069240918919495804, 'step_size': 0.033489574142671445, 'cooling': 0.9426845695259322, 'max_epochs': 189}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:45,506] Trial 57 finished with value: 0.52 and parameters: {'t': 0.836418837135042, 't_min': 0.00834551931793324, 'step_size': 0.03478119186381045, 'cooling': 0.9277078491454332, 'max_epochs': 138}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:45,725] Trial 58 finished with value: 0.43 and parameters: {'t': 0.5832117546181773, 't_min': 0.00831826806415214, 'step_size': 0.026034949756740776, 'cooling': 0.9058910961426712, 'max_epochs': 160}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:45,923] Trial 59 finished with value: 0.435 and parameters: {'t': 0.5863545809680443, 't_min': 0.008226432124952849, 'step_size': 0.0485911210054881, 'cooling': 0.9173262530058881, 'max_epochs': 101}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:46,121] Trial 60 finished with value: 0.395 and parameters: {'t': 0.8837895968781929, 't_min': 0.008409150211383396, 'step_size': 0.0461218738776972, 'cooling': 0.9172472761420565, 'max_epochs': 137}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:46,336] Trial 61 finished with value: 0.565 and parameters: {'t': 0.5384839199174525, 't_min': 0.003138423439140499, 'step_size': 0.04847474117943608, 'cooling': 0.9176015720419415, 'max_epochs': 157}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:46,607] Trial 62 finished with value: 0.5 and parameters: {'t': 1.4975649118333696, 't_min': 0.00540002906557372, 'step_size': 0.03146528105558826, 'cooling': 0.988687132802067, 'max_epochs': 175}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:46,887] Trial 63 finished with value: 0.395 and parameters: {'t': 1.6091157255398552, 't_min': 0.004511737592382741, 'step_size': 0.04051693720321982, 'cooling': 0.9267385187174364, 'max_epochs': 36}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:47,143] Trial 64 finished with value: 0.52 and parameters: {'t': 1.6041541088937117, 't_min': 0.004921533594941978, 'step_size': 0.0455639450169614, 'cooling': 0.9538699325737466, 'max_epochs': 37}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:47,330] Trial 65 finished with value: 0.44 and parameters: {'t': 1.5988192595927813, 't_min': 0.001631823164868546, 'step_size': 0.045689085021758044, 'cooling': 0.9878220475083546, 'max_epochs': 33}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:47,555] Trial 66 finished with value: 0.435 and parameters: {'t': 1.6310132138029774, 't_min': 0.0018671467463640384, 'step_size': 0.02505970419117977, 'cooling': 0.9541928293552226, 'max_epochs': 17}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:47,822] Trial 67 finished with value: 0.49 and parameters: {'t': 1.710699309246503, 't_min': 0.0016679709500424453, 'step_size': 0.047157120751726816, 'cooling': 0.9589211170633035, 'max_epochs': 13}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:48,080] Trial 68 finished with value: 0.5 and parameters: {'t': 1.6874644956492981, 't_min': 0.0015049658385029275, 'step_size': 0.047077194141676305, 'cooling': 0.9516721264317752, 'max_epochs': 122}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:48,341] Trial 69 finished with value: 0.435 and parameters: {'t': 0.6456030046783026, 't_min': 0.009981036617555413, 'step_size': 0.04716913417552491, 'cooling': 0.9138902356253777, 'max_epochs': 88}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:48,575] Trial 70 finished with value: 0.56 and parameters: {'t': 0.6432050945424101, 't_min': 0.006419238414355817, 'step_size': 0.046940955688722724, 'cooling': 0.9578724863098605, 'max_epochs': 119}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:48,746] Trial 71 finished with value: 0.555 and parameters: {'t': 1.52002472848811, 't_min': 0.0064140544363145875, 'step_size': 0.04250528394255916, 'cooling': 0.9143749260048555, 'max_epochs': 122}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:48,987] Trial 72 finished with value: 0.565 and parameters: {'t': 1.4855089976815963, 't_min': 0.00972316081049621, 'step_size': 0.03672104633723806, 'cooling': 0.914770176773726, 'max_epochs': 100}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:49,214] Trial 73 finished with value: 0.5 and parameters: {'t': 1.5187869575951178, 't_min': 0.009429236420292475, 'step_size': 0.04250939099462505, 'cooling': 0.9007457525311693, 'max_epochs': 27}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:49,444] Trial 74 finished with value: 0.565 and parameters: {'t': 0.5069317091367825, 't_min': 0.007769898978757365, 'step_size': 0.032685198907715166, 'cooling': 0.9377219318401055, 'max_epochs': 200}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:49,659] Trial 75 finished with value: 0.385 and parameters: {'t': 0.5164658536144027, 't_min': 0.007971221464819572, 'step_size': 0.037031011034384595, 'cooling': 0.9388574325331349, 'max_epochs': 50}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:49,859] Trial 76 finished with value: 0.565 and parameters: {'t': 0.5156797577431368, 't_min': 0.007870226070418616, 'step_size': 0.03232874881925888, 'cooling': 0.9370898558292182, 'max_epochs': 200}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:50,071] Trial 77 finished with value: 0.565 and parameters: {'t': 0.5038182503953632, 't_min': 0.00731749078924265, 'step_size': 0.0324165094642341, 'cooling': 0.9390493893492988, 'max_epochs': 200}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:50,328] Trial 78 finished with value: 0.495 and parameters: {'t': 0.6924479362463218, 't_min': 0.007510142727749087, 'step_size': 0.03511309232679024, 'cooling': 0.9459901282816857, 'max_epochs': 177}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:50,561] Trial 79 finished with value: 0.385 and parameters: {'t': 1.3896747119723134, 't_min': 0.008619079096900725, 'step_size': 0.0358577816198814, 'cooling': 0.9672059670863646, 'max_epochs': 179}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:50,797] Trial 80 finished with value: 0.565 and parameters: {'t': 0.7249635931638193, 't_min': 0.007441123417997771, 'step_size': 0.03538223893095855, 'cooling': 0.945271949952829, 'max_epochs': 177}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:50,983] Trial 81 finished with value: 0.565 and parameters: {'t': 0.7252671977216044, 't_min': 0.0013425345537322435, 'step_size': 0.03589504909304218, 'cooling': 0.9345091939501652, 'max_epochs': 176}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:51,243] Trial 82 finished with value: 0.525 and parameters: {'t': 1.283171666224154, 't_min': 0.0020341920371283306, 'step_size': 0.028342405736554357, 'cooling': 0.9679979464870412, 'max_epochs': 177}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:51,466] Trial 83 finished with value: 0.395 and parameters: {'t': 0.7350186123795565, 't_min': 0.0013886038304205964, 'step_size': 0.02899673857282649, 'cooling': 0.929442122211351, 'max_epochs': 88}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:51,682] Trial 84 finished with value: 0.395 and parameters: {'t': 0.5489378303407229, 't_min': 0.009780512321722659, 'step_size': 0.02878775619646427, 'cooling': 0.9287164256353471, 'max_epochs': 193}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:51,908] Trial 85 finished with value: 0.565 and parameters: {'t': 0.6004120323887812, 't_min': 0.0019962801052416327, 'step_size': 0.03130056142330922, 'cooling': 0.928129591927725, 'max_epochs': 191}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:52,152] Trial 86 finished with value: 0.565 and parameters: {'t': 0.5656186787465426, 't_min': 0.009081965194514477, 'step_size': 0.030668008580795967, 'cooling': 0.9294705775360187, 'max_epochs': 194}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:52,381] Trial 87 finished with value: 0.565 and parameters: {'t': 0.6334149078199574, 't_min': 0.0010096340262010545, 'step_size': 0.030702121474610895, 'cooling': 0.9222443668257795, 'max_epochs': 191}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:52,604] Trial 88 finished with value: 0.565 and parameters: {'t': 0.6353829912879128, 't_min': 0.0010607009235176624, 'step_size': 0.03159463661127887, 'cooling': 0.921786093502678, 'max_epochs': 194}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:52,825] Trial 89 finished with value: 0.555 and parameters: {'t': 1.7743088108162723, 't_min': 0.0010105127687007657, 'step_size': 0.04135051240637701, 'cooling': 0.9211586975551922, 'max_epochs': 183}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:53,036] Trial 90 finished with value: 0.56 and parameters: {'t': 1.7856431125249381, 't_min': 0.002592271213181525, 'step_size': 0.04046514905261202, 'cooling': 0.9210042147703565, 'max_epochs': 111}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:53,306] Trial 91 finished with value: 0.555 and parameters: {'t': 1.8708965409440035, 't_min': 0.007162290397902293, 'step_size': 0.041260363306128714, 'cooling': 0.9515236126183825, 'max_epochs': 184}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:53,580] Trial 92 finished with value: 0.56 and parameters: {'t': 1.7901068793499417, 't_min': 0.002862463549692649, 'step_size': 0.039641725401767566, 'cooling': 0.9054720064758586, 'max_epochs': 183}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:53,831] Trial 93 finished with value: 0.555 and parameters: {'t': 1.165605918944832, 't_min': 0.00919968964433695, 'step_size': 0.043861248278838874, 'cooling': 0.9053517581221984, 'max_epochs': 171}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:54,107] Trial 94 finished with value: 0.565 and parameters: {'t': 0.8041472158266326, 't_min': 0.0071667739752483564, 'step_size': 0.033141283871622074, 'cooling': 0.941936741205201, 'max_epochs': 186}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:54,393] Trial 95 finished with value: 0.565 and parameters: {'t': 0.893729268618332, 't_min': 0.006162537980188553, 'step_size': 0.034337975936529375, 'cooling': 0.9412633134185874, 'max_epochs': 172}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:54,645] Trial 96 finished with value: 0.565 and parameters: {'t': 1.170470803110275, 't_min': 0.009440507685911327, 'step_size': 0.033210256264540834, 'cooling': 0.9409962889540446, 'max_epochs': 99}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:54,901] Trial 97 finished with value: 0.565 and parameters: {'t': 0.9108015713556168, 't_min': 0.009502457457518463, 'step_size': 0.03286056103966316, 'cooling': 0.9630669489096059, 'max_epochs': 196}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:55,143] Trial 98 finished with value: 0.565 and parameters: {'t': 0.9011259416262458, 't_min': 0.008122505426822314, 'step_size': 0.03429369281113212, 'cooling': 0.9455196011542711, 'max_epochs': 196}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:55,368] Trial 99 finished with value: 0.56 and parameters: {'t': 1.0704237142812694, 't_min': 0.0065525963482273575, 'step_size': 0.02938800712004168, 'cooling': 0.9452541164671369, 'max_epochs': 57}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:55,599] Trial 100 finished with value: 0.565 and parameters: {'t': 1.3454146954963933, 't_min': 0.008042939904266005, 'step_size': 0.04774365699256829, 'cooling': 0.9451806867494265, 'max_epochs': 59}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:55,840] Trial 101 finished with value: 0.565 and parameters: {'t': 1.0954806675165165, 't_min': 0.008632605534647113, 'step_size': 0.03178994703165597, 'cooling': 0.9458195022442966, 'max_epochs': 51}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:56,044] Trial 102 finished with value: 0.565 and parameters: {'t': 1.035504755374633, 't_min': 0.006684771101678726, 'step_size': 0.03181171397247801, 'cooling': 0.9342443739040635, 'max_epochs': 57}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:56,300] Trial 103 finished with value: 0.56 and parameters: {'t': 1.3513673595234825, 't_min': 0.005280762226754534, 'step_size': 0.049028773048955004, 'cooling': 0.9254708708521724, 'max_epochs': 163}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:56,523] Trial 104 finished with value: 0.56 and parameters: {'t': 0.9474942540208761, 't_min': 0.008502378063482351, 'step_size': 0.049107169581874596, 'cooling': 0.9354275101466599, 'max_epochs': 97}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:56,804] Trial 105 finished with value: 0.565 and parameters: {'t': 1.041966209120549, 't_min': 0.00881445527654124, 'step_size': 0.03766987826118778, 'cooling': 0.9351937636432427, 'max_epochs': 93}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:57,017] Trial 106 finished with value: 0.56 and parameters: {'t': 0.9786109054638656, 't_min': 0.009981539744836865, 'step_size': 0.04929611812855519, 'cooling': 0.9022574532117391, 'max_epochs': 93}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:57,270] Trial 107 finished with value: 0.565 and parameters: {'t': 1.2278441975691146, 't_min': 0.009699484260205435, 'step_size': 0.0339246105685876, 'cooling': 0.903024029091283, 'max_epochs': 94}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:57,530] Trial 108 finished with value: 0.555 and parameters: {'t': 1.225113610502547, 't_min': 0.00986605915127632, 'step_size': 0.044912408920990576, 'cooling': 0.9080192696352626, 'max_epochs': 92}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:57,760] Trial 109 finished with value: 0.555 and parameters: {'t': 1.0053430217431447, 't_min': 0.00996421737119522, 'step_size': 0.026960335119006265, 'cooling': 0.9016225204750435, 'max_epochs': 104}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:57,987] Trial 110 finished with value: 0.565 and parameters: {'t': 0.6776105510453432, 't_min': 0.007678180666304332, 'step_size': 0.0344499800494295, 'cooling': 0.9079868118425772, 'max_epochs': 105}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:58,191] Trial 111 finished with value: 0.555 and parameters: {'t': 0.6722001396498176, 't_min': 0.004398970767360828, 'step_size': 0.02672698625901552, 'cooling': 0.9085100404270542, 'max_epochs': 106}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:58,374] Trial 112 finished with value: 0.565 and parameters: {'t': 0.6694529700560197, 't_min': 0.00229475463962693, 'step_size': 0.034667332788006926, 'cooling': 0.9315046371262246, 'max_epochs': 82}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:58,638] Trial 113 finished with value: 0.555 and parameters: {'t': 0.8437437453268775, 't_min': 0.0022047513837341287, 'step_size': 0.04376864842606405, 'cooling': 0.9780452891163708, 'max_epochs': 133}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:58,898] Trial 114 finished with value: 0.5 and parameters: {'t': 1.1509988664813957, 't_min': 0.0023969935946753685, 'step_size': 0.04585115499429727, 'cooling': 0.9504800406828977, 'max_epochs': 82}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:59,115] Trial 115 finished with value: 0.4 and parameters: {'t': 1.143429514349937, 't_min': 0.0022717281964337193, 'step_size': 0.04779597026538414, 'cooling': 0.9647633237100708, 'max_epochs': 130}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:59,348] Trial 116 finished with value: 0.565 and parameters: {'t': 1.1182886157158554, 't_min': 0.0023892074576235918, 'step_size': 0.04786412933571463, 'cooling': 0.9769591363130967, 'max_epochs': 188}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:59,575] Trial 117 finished with value: 0.565 and parameters: {'t': 1.2942203063708286, 't_min': 0.0018326333442877645, 'step_size': 0.048340980724053975, 'cooling': 0.9621294762072804, 'max_epochs': 188}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:04:59,827] Trial 118 finished with value: 0.565 and parameters: {'t': 1.2934344300882386, 't_min': 0.005827954859297331, 'step_size': 0.0479024286609999, 'cooling': 0.9559297383598113, 'max_epochs': 187}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:00,051] Trial 119 finished with value: 0.565 and parameters: {'t': 1.2790829252226987, 't_min': 0.00575208222450374, 'step_size': 0.048451597185475405, 'cooling': 0.9568892314780177, 'max_epochs': 45}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:00,280] Trial 120 finished with value: 0.56 and parameters: {'t': 0.5459787634616591, 't_min': 0.009078114974324748, 'step_size': 0.04648223965603682, 'cooling': 0.9605187726374748, 'max_epochs': 46}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:00,482] Trial 121 finished with value: 0.56 and parameters: {'t': 1.1970993002103505, 't_min': 0.009171433736701295, 'step_size': 0.046315995265734086, 'cooling': 0.9553936907965945, 'max_epochs': 42}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:00,756] Trial 122 finished with value: 0.56 and parameters: {'t': 0.9430950937231277, 't_min': 0.009554293776997118, 'step_size': 0.03034207592391478, 'cooling': 0.9719167996860306, 'max_epochs': 114}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:00,981] Trial 123 finished with value: 0.56 and parameters: {'t': 1.994272572806537, 't_min': 0.003418423010511649, 'step_size': 0.04623238439526791, 'cooling': 0.9715702048684483, 'max_epochs': 142}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:01,200] Trial 124 finished with value: 0.555 and parameters: {'t': 0.9435099076164519, 't_min': 0.003013926542043833, 'step_size': 0.04496145832403606, 'cooling': 0.9729544269174035, 'max_epochs': 65}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:01,418] Trial 125 finished with value: 0.395 and parameters: {'t': 0.946872444896602, 't_min': 0.0014047878872714148, 'step_size': 0.03351469943542459, 'cooling': 0.9703164404110398, 'max_epochs': 166}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:01,666] Trial 126 finished with value: 0.56 and parameters: {'t': 1.4246835121123174, 't_min': 0.002811039243204457, 'step_size': 0.04998692375892684, 'cooling': 0.9720356223696962, 'max_epochs': 153}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:01,898] Trial 127 finished with value: 0.565 and parameters: {'t': 0.5707861052774779, 't_min': 0.002866962689638554, 'step_size': 0.03213620568198467, 'cooling': 0.9112818819075119, 'max_epochs': 66}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:02,125] Trial 128 finished with value: 0.565 and parameters: {'t': 1.4519594883004938, 't_min': 0.0014632374235668153, 'step_size': 0.0354768698432798, 'cooling': 0.968025819952218, 'max_epochs': 153}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:02,370] Trial 129 finished with value: 0.565 and parameters: {'t': 0.5795487158508092, 't_min': 0.002057381999098883, 'step_size': 0.03524317118755474, 'cooling': 0.969015183863384, 'max_epochs': 159}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:02,578] Trial 130 finished with value: 0.565 and parameters: {'t': 0.5950042190964453, 't_min': 0.00198345525634287, 'step_size': 0.0353767458794169, 'cooling': 0.9191745277074759, 'max_epochs': 85}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:02,791] Trial 131 finished with value: 0.565 and parameters: {'t': 1.252785521616569, 't_min': 0.003671632427892496, 'step_size': 0.03541977078543645, 'cooling': 0.9657732235066698, 'max_epochs': 126}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:03,025] Trial 132 finished with value: 0.565 and parameters: {'t': 1.188131465747819, 't_min': 0.002075740286766767, 'step_size': 0.035013134471504406, 'cooling': 0.952993485692418, 'max_epochs': 181}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:03,276] Trial 133 finished with value: 0.5 and parameters: {'t': 1.0727338986965356, 't_min': 0.007621756935357536, 'step_size': 0.03274201631808814, 'cooling': 0.9312946198033085, 'max_epochs': 173}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:03,511] Trial 134 finished with value: 0.515 and parameters: {'t': 1.1000231651706092, 't_min': 0.0017551328762881197, 'step_size': 0.03607987739194085, 'cooling': 0.9818051199618063, 'max_epochs': 171}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:03,711] Trial 135 finished with value: 0.385 and parameters: {'t': 1.1208286493388229, 't_min': 0.002563777817390449, 'step_size': 0.036344059664686935, 'cooling': 0.9832401512055328, 'max_epochs': 179}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:03,911] Trial 136 finished with value: 0.565 and parameters: {'t': 1.102314521180968, 't_min': 0.002646466190650458, 'step_size': 0.03749069105943506, 'cooling': 0.9750856310507426, 'max_epochs': 174}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:04,217] Trial 137 finished with value: 0.565 and parameters: {'t': 1.1047817627494936, 't_min': 0.001603833124576534, 'step_size': 0.036518702933262204, 'cooling': 0.9830186599391937, 'max_epochs': 197}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:04,457] Trial 138 finished with value: 0.5 and parameters: {'t': 1.1256315378315112, 't_min': 0.0026923793977568847, 'step_size': 0.037146471058057774, 'cooling': 0.9486694126119645, 'max_epochs': 167}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:04,689] Trial 139 finished with value: 0.405 and parameters: {'t': 1.568464626159813, 't_min': 0.006028410377455343, 'step_size': 0.04302732006881958, 'cooling': 0.939656937953011, 'max_epochs': 166}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:04,842] Trial 140 finished with value: 0.555 and parameters: {'t': 1.055068334774362, 't_min': 0.0012307945390370382, 'step_size': 0.04299225158206753, 'cooling': 0.9395826082782531, 'max_epochs': 195}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:05,115] Trial 141 finished with value: 0.565 and parameters: {'t': 1.9489025459828058, 't_min': 0.00711530712156111, 'step_size': 0.03110245897604014, 'cooling': 0.9393909233019999, 'max_epochs': 167}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:05,347] Trial 142 finished with value: 0.5 and parameters: {'t': 1.0571449479146127, 't_min': 0.006106343893857967, 'step_size': 0.039075500295364836, 'cooling': 0.9584369893140532, 'max_epochs': 75}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:05,611] Trial 143 finished with value: 0.485 and parameters: {'t': 0.537939865808631, 't_min': 0.009642861037354282, 'step_size': 0.04739597388912532, 'cooling': 0.9039102438300266, 'max_epochs': 160}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:05,781] Trial 144 finished with value: 0.52 and parameters: {'t': 0.5436283890639569, 't_min': 0.003141499185014623, 'step_size': 0.033868010080534576, 'cooling': 0.9173252372394224, 'max_epochs': 77}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:06,001] Trial 145 finished with value: 0.395 and parameters: {'t': 0.5435633127283421, 't_min': 0.009746391066684549, 'step_size': 0.03381344359357251, 'cooling': 0.9173027314592657, 'max_epochs': 160}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:06,236] Trial 146 finished with value: 0.565 and parameters: {'t': 0.5380187717474143, 't_min': 0.0029966287087956835, 'step_size': 0.0338180149952002, 'cooling': 0.9174996968464693, 'max_epochs': 192}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:06,448] Trial 147 finished with value: 0.435 and parameters: {'t': 1.8831543048432071, 't_min': 0.007940885604601218, 'step_size': 0.048814476387268164, 'cooling': 0.9134120110685165, 'max_epochs': 27}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:06,627] Trial 148 finished with value: 0.515 and parameters: {'t': 0.6210554968028688, 't_min': 0.006764950633558966, 'step_size': 0.04893490362127746, 'cooling': 0.9159751401861764, 'max_epochs': 156}. Best is trial 3 with value: 0.86.
# [I 2025-12-12 03:05:06,761] Trial 149 finished with value: 0.39 and parameters: {'t': 1.899123877038218, 't_min': 0.008894983764824392, 'step_size': 0.04876278311726361, 'cooling': 0.9431747858572821, 'max_epochs': 156}. Best is trial 3 with value: 0.86.
# Best parameters: {'t': 0.5835824769050657, 't_min': 0.001810413819371178, 'step_size': 0.0457338679570872, 'cooling': 0.9281705505474588, 'max_epochs': 92}
# Best score: 0.86
# Best trial: 3
