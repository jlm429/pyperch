# %% [markdown]
# ## Hybric RHC + Adam Neural Net Example

# %%
# Install pyperch if needed
# !pip install pyperch

import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

from pyperch.optim.rhc import RHC

# Set seed for reproducibility
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

# Generate synthetic data
X, y = make_classification(n_samples=1000, n_features=12, n_informative=10, random_state=seed)
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.long)

# Train/val split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed)

# Define the model with two hidden layers
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden1 = nn.Linear(12, 32)
        self.hidden2 = nn.Linear(32, 16)
        self.output = nn.Linear(16, 2)

    def forward(self, x):
        x = F.relu(self.hidden1(x))
        x = F.relu(self.hidden2(x))
        return self.output(x)

model = MLP()
criterion = nn.CrossEntropyLoss()

# Separate parameter groups for optimizers
rhc_params = list(model.hidden1.parameters())  # RHC on first hidden layer
adam_params = list(model.hidden2.parameters()) + list(model.output.parameters())  # Adam on rest

# Instantiate optimizers
rhc_opt = RHC(rhc_params, step_size=0.05, max_no_improve=3, n_restarts=3, random_state=seed)
adam_opt = torch.optim.Adam(adam_params, lr=1e-3)

# Training loop
epochs = 50
train_losses = []
val_losses = []

for epoch in range(epochs):
    def rhc_closure():
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        return loss.item()  # Do not call backward()

    # Step RHC first (derivative-free)
    rhc_loss = rhc_opt.step(rhc_closure)

    # Then run Adam optimizer (gradient-based)
    model.train()
    adam_opt.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    adam_opt.step()

    # Evaluate validation loss
    model.eval()
    with torch.no_grad():
        val_outputs = model(X_val)
        val_loss = criterion(val_outputs, y_val).item()

    train_losses.append(loss.item())  # use final loss after Adam step
    val_losses.append(val_loss)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {loss:.4f}, Val Loss: {val_loss:.4f}")
# Out:
# Requirement already satisfied: pyperch in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (0.1.3)
# Requirement already satisfied: skorch<=1.0.0,>=0.15.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from pyperch) (1.0.0)
# Requirement already satisfied: torch<2.4.0,>=2.2.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from pyperch) (2.2.1)
# Requirement already satisfied: scikit-learn<=1.4.2 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from pyperch) (1.4.2)
# Requirement already satisfied: numpy in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from pyperch) (1.26.4)
# Requirement already satisfied: matplotlib in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from pyperch) (3.8.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from scikit-learn<=1.4.2->pyperch) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from scikit-learn<=1.4.2->pyperch) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from scikit-learn<=1.4.2->pyperch) (3.4.0)
# Requirement already satisfied: tabulate>=0.7.7 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from skorch<=1.0.0,>=0.15.0->pyperch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from skorch<=1.0.0,>=0.15.0->pyperch) (4.66.2)
# Requirement already satisfied: filelock in /home/john/.local/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (4.10.0)
# Requirement already satisfied: sympy in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (1.12)
# Requirement already satisfied: networkx in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (3.1.3)
# Requirement already satisfied: fsspec in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from torch<2.4.0,>=2.2.0->pyperch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.4.0,>=2.2.0->pyperch) (12.4.99)
# Requirement already satisfied: contourpy>=1.0.1 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from matplotlib->pyperch) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->pyperch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from jinja2->torch<2.4.0,>=2.2.0->pyperch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/john/anaconda3/envs/pyperch/lib/python3.11/site-packages (from sympy->torch<2.4.0,>=2.2.0->pyperch) (1.3.0)
# Epoch 1/50, Train Loss: 0.6939, Val Loss: 0.6888
# Epoch 2/50, Train Loss: 0.6884, Val Loss: 0.6836
# Epoch 3/50, Train Loss: 0.6828, Val Loss: 0.6766
# Epoch 4/50, Train Loss: 0.6792, Val Loss: 0.6756
# Epoch 5/50, Train Loss: 0.6761, Val Loss: 0.6726
# Epoch 6/50, Train Loss: 0.6728, Val Loss: 0.6693
# Epoch 7/50, Train Loss: 0.6691, Val Loss: 0.6654
# Epoch 8/50, Train Loss: 0.6607, Val Loss: 0.6580
# Epoch 9/50, Train Loss: 0.6530, Val Loss: 0.6530
# Epoch 10/50, Train Loss: 0.6468, Val Loss: 0.6467
# Epoch 11/50, Train Loss: 0.6418, Val Loss: 0.6417
# Epoch 12/50, Train Loss: 0.6306, Val Loss: 0.6279
# Epoch 13/50, Train Loss: 0.6263, Val Loss: 0.6238
# Epoch 14/50, Train Loss: 0.6186, Val Loss: 0.6164
# Epoch 15/50, Train Loss: 0.6120, Val Loss: 0.6088
# Epoch 16/50, Train Loss: 0.5970, Val Loss: 0.5952
# Epoch 17/50, Train Loss: 0.5918, Val Loss: 0.5873
# Epoch 18/50, Train Loss: 0.5856, Val Loss: 0.5793
# Epoch 19/50, Train Loss: 0.5742, Val Loss: 0.5697
# Epoch 20/50, Train Loss: 0.5588, Val Loss: 0.5575
# Epoch 21/50, Train Loss: 0.5531, Val Loss: 0.5522
# Epoch 22/50, Train Loss: 0.5481, Val Loss: 0.5475
# Epoch 23/50, Train Loss: 0.5396, Val Loss: 0.5377
# Epoch 24/50, Train Loss: 0.5346, Val Loss: 0.5338
# Epoch 25/50, Train Loss: 0.5301, Val Loss: 0.5297
# Epoch 26/50, Train Loss: 0.5257, Val Loss: 0.5260
# Epoch 27/50, Train Loss: 0.5204, Val Loss: 0.5211
# Epoch 28/50, Train Loss: 0.5137, Val Loss: 0.5135
# Epoch 29/50, Train Loss: 0.5054, Val Loss: 0.5060
# Epoch 30/50, Train Loss: 0.4976, Val Loss: 0.4985
# Epoch 31/50, Train Loss: 0.4886, Val Loss: 0.4930
# Epoch 32/50, Train Loss: 0.4779, Val Loss: 0.4813
# Epoch 33/50, Train Loss: 0.4681, Val Loss: 0.4678
# Epoch 34/50, Train Loss: 0.4606, Val Loss: 0.4613
# Epoch 35/50, Train Loss: 0.4504, Val Loss: 0.4494
# Epoch 36/50, Train Loss: 0.4456, Val Loss: 0.4451
# Epoch 37/50, Train Loss: 0.4406, Val Loss: 0.4410
# Epoch 38/50, Train Loss: 0.4269, Val Loss: 0.4324
# Epoch 39/50, Train Loss: 0.4218, Val Loss: 0.4280
# Epoch 40/50, Train Loss: 0.4174, Val Loss: 0.4245
# Epoch 41/50, Train Loss: 0.4123, Val Loss: 0.4203
# Epoch 42/50, Train Loss: 0.4060, Val Loss: 0.4173
# Epoch 43/50, Train Loss: 0.3963, Val Loss: 0.4049
# Epoch 44/50, Train Loss: 0.3769, Val Loss: 0.3842
# Epoch 45/50, Train Loss: 0.3712, Val Loss: 0.3775
# Epoch 46/50, Train Loss: 0.3626, Val Loss: 0.3713
# Epoch 47/50, Train Loss: 0.3578, Val Loss: 0.3704
# Epoch 48/50, Train Loss: 0.3533, Val Loss: 0.3667
# Epoch 49/50, Train Loss: 0.3476, Val Loss: 0.3614
# Epoch 50/50, Train Loss: 0.3426, Val Loss: 0.3557

# %%
# Plot learning curves
plt.plot(train_losses, label='Train Loss', color='navy')
plt.plot(val_losses, label='Validation Loss', color='lightcoral')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Hybrid RHC + Adam Learning Curve")
plt.grid(visible=True)
plt.legend(frameon=False)
plt.show()
